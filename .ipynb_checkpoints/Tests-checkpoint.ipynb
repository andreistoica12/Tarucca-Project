# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# I imported 2 previously used datasets from the company's database

# %%
df_40rpm = pd.read_csv("data/SubsetB_undamaged_40rpm_raw.csv")
df_idle = pd.read_csv("data/SubsetB_undamaged_idle_raw.csv")
print(len(df_40rpm))    # 44550000 entries
print(len(df_idle))     # 900000 entries
# Out:
# 44550000
# 900000

# %%
df_40rpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44550000 entries, 0 to 44549999
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       float64
#  1   1       float64
# dtypes: float64(2)
# memory usage: 679.8 MB

# %%
sensor8 = df_40rpm.iloc[:, 0]

# %%
sensor8.isna().sum()
# Out:
# 0

# %% [markdown]
# We can see that there is no value missing in the dataset, so the preprocessing part is done. We can see some methods to preprocess the raw data here: https://towardsdatascience.com/anomaly-detection-in-time-series-sensor-data-86fd52e62538

# %%
sensor8.plot.hist(bins=100, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print(df_40rpm.iloc[0:10, :])
# Out:
#           0         1
# 0 -2.106398 -0.926999
# 1 -2.264100 -0.795058
# 2 -2.578189 -0.867711
# 3 -1.468282 -0.793636
# 4 -1.243202 -0.794347
# 5 -2.294939 -1.048276
# 6 -1.721278 -1.051404
# 7 -0.773895 -1.040883
# 8 -0.338351 -1.052542
# 9 -1.454251 -1.116380

# %%
plt.plot(sensor8.index[20000:70000], sensor8[20000:70000])
plt.plot(sensor8.index[70000:120000], sensor8[70000:120000])
plt.plot(sensor8.index[120000:170000], sensor8[120000:170000])
plt.plot(sensor8.index[170000:220000], sensor8[170000:220000])

# %%
s = sensor8

# %% [markdown]
# The sensors have a sampling rate of 16 kHz, meaning they record 16 * 1000 = 16000 entries/second.

# %%
plt.plot(sensor8.index[0:16000], sensor8[0:16000])

# %%
plt.plot(sensor8.index[:], sensor8[:])

# %%
sensor8.describe()
# Out:
# count    4.455000e+07
# mean    -2.829765e-03
# std      4.181142e+00
# min     -2.066366e+01
# 25%     -3.389939e+00
# 50%     -1.578483e-02
# 75%      3.331915e+00
# max      2.031859e+01
# Name: 0, dtype: float64

# %% [markdown]
# The time series in not stationary, we cannot see any trend over time in the lot above.

# %%
import scipy

# %%
print(scipy.__file__)
# Out:
# C:\Users\catas\anaconda3\lib\site-packages\scipy\__init__.py

# %% [markdown]
# An outline of the data:

# %%
df_40rpm.shape
# Out:
# (44550000, 2)

# %%
df_40rpm.keys()
# Out:
# Index(['0', '1'], dtype='object')

# %%
df_40rpm.head()
# Out:
#           0         1
# 0 -2.106398 -0.926999
# 1 -2.264100 -0.795058
# 2 -2.578189 -0.867711
# 3 -1.468282 -0.793636
# 4 -1.243202 -0.794347

# %%
import seaborn as sns

# %%
df_40rpm.columns
# Out:
# Index(['0', '1'], dtype='object')

# %%
df_40rpm['1'][:]
# Out:
# 0          -0.926999
# 1          -0.795058
# 2          -0.867711
# 3          -0.793636
# 4          -0.794347
#               ...
# 44549995    1.387370
# 44549996    1.290689
# 44549997    1.170976
# 44549998    1.062921
# 44549999    0.658852
# Name: 1, Length: 44550000, dtype: float64

# %%
df_40rpm.rename(columns = {'0':'sensor8', '1':'sensor9'}, inplace = True)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %%
target
